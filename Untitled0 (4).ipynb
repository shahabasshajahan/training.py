# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("List:",list)
# Out:
# Enter list size:3
# Enter the elements in the list12
# Enter the elements in the list36
# Enter the elements in the list56
# List: [12, 36, 56]
