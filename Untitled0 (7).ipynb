# %%
a=int(input("Enter the no of elements"))
sum=0
for i in range(a):
  b=int(input("Enter element"))
  sum=sum+b
print("sum of elements is",sum)
# Out:
# Enter the no of elements3
# Enter element9
# Enter element8
# Enter element7
# sum of elements is 24
