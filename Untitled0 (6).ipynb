# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
smallest=min(num)
print(num)
print("smallest element is",smallest)
# Out:
# enter the total no of elements2
# enter the number8
# enter the number5
# [8, 5]
# smallest element is 5
