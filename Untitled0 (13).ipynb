# %%
n=int(input("enter the limit"))
arr=[]
for i in range(n):
  arr.append(int(input("enter the element")))
print("arr=",arr)
arr.sort()
print("sorted array is",arr)
# Out:
# enter the limit10
# enter the element9
# enter the element8
# enter the element7
# enter the element6
# enter the element5
# enter the element4
# enter the element3
# enter the element2
# enter the element1
# enter the element5
# arr= [9, 8, 7, 6, 5, 4, 3, 2, 1, 5]
# sorted array is [1, 2, 3, 4, 5, 5, 6, 7, 8, 9]
