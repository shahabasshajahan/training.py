# %%
n=int(input("Enter the no of elements:"))
l=[]
for i in range(n):
  l.append(int(input("enter the elments:")))
print("list=",l)
print("a[:]",l[:])
print("a[2:]",l[2:])
print("a[2:4]",l[2:4])
print("a[:3]",l[:3])
print("a[2:5:2]",l[2:5:2])
# Out:
# Enter the no of elements:3
# enter the elments:2
# enter the elments:5
# enter the elments:8
# list= [2, 5, 8]
# a[:] [2, 5, 8]
# a[2:] [8]
# a[2:4] [8]
# a[:3] [2, 5, 8]
# a[2:5:2] [8]
