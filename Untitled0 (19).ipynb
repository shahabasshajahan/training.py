# %%
str1=input("enter the string:")
str2=input("enter the string:")
if(sorted(str1)==sorted(str2)):
  print("anagram")
else:
  print("not anagram")
# Out:
# enter the string:50
# enter the string:25
# not anagram

# %%
a=input("Enter a string: ")
count=0
for i in a:
     count+=1
print("Total characters without built in",count)
print("Total characters with built in",len(a))
# Out:
# Enter a string: 74
# Total characters without built in 2
# Total characters with built in 2
