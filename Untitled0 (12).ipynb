# %%
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)
# Out:
# Enter the no. of elements: 9
# Enter the element: 1
# Enter the element: 2
# Enter the element: 2
# Enter the element: 3
# Enter the element: 4
# Enter the element: 2
# Enter the element: 5
# Enter the element: 1
# Enter the element: 6
# List= [1, 2, 2, 3, 4, 2, 5, 1, 6]
# Updated list= [1, 2, 3, 4, 5, 6]
